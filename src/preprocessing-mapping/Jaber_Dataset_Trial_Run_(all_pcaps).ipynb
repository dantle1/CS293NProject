# %%
# !git clone https://github.com/dantle1/CS293NProject.git
# Out:
# Cloning into 'CS293NProject'...
# remote: Enumerating objects: 1107, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 1107 (delta 1), reused 0 (delta 0), pack-reused 1100 (from 5)
# Receiving objects: 100% (1107/1107), 1.22 GiB | 25.06 MiB/s, done.
# Resolving deltas: 100% (959/959), done.
# Updating files: 100% (1061/1061), done.

# %%
# TShark Packet Extraction Script for Google Colab (Filtered by IP)
# Project: CS 293N - Raw Packet Filtering from PCAP

import os
import pandas as pd
from datetime import datetime, timedelta
import glob
import numpy as np

# %%
# Install TShark
# !apt-get install -y tshark
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libbcg729-0 libc-ares2 liblua5.2-0 libnl-genl-3-200 libpcap0.8 libsbc1
#   libsmi2ldbl libspandsp2 libspeexdsp1 libwireshark-data libwireshark15
#   libwiretap12 libwsutil13 wireshark-common
# Suggested packages:
#   snmp-mibs-downloader geoipupdate geoip-database geoip-database-extra
#   libjs-leaflet libjs-leaflet.markercluster wireshark-doc
# The following NEW packages will be installed:
#   libbcg729-0 libc-ares2 liblua5.2-0 libnl-genl-3-200 libpcap0.8 libsbc1
#   libsmi2ldbl libspandsp2 libspeexdsp1 libwireshark-data libwireshark15
#   libwiretap12 libwsutil13 tshark wireshark-common
# 0 upgraded, 15 newly installed, 0 to remove and 35 not upgraded.
# Need to get 23.0 MB of archives.
# After this operation, 120 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap0.8 amd64 1.10.1-4ubuntu1.22.04.1 [145 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbcg729-0 amd64 1.1.1-2 [32.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblua5.2-0 amd64 5.2.4-2 [125 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnl-genl-3-200 amd64 3.5.0-0.1 [12.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsmi2ldbl amd64 0.4.8+dfsg2-16 [100 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libspeexdsp1 amd64 1.2~rc1.2-1.1ubuntu3 [42.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwireshark-data all 3.6.2-2 [1,647 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsbc1 amd64 1.5-3build2 [34.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwsutil13 amd64 3.6.2-2 [99.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwiretap12 amd64 3.6.2-2 [255 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwireshark15 amd64 3.6.2-2 [19.5 MB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 wireshark-common amd64 3.6.2-2 [473 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tshark amd64 3.6.2-2 [157 kB]
# Fetched 23.0 MB in 3s (8,894 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package libpcap0.8:amd64.
# (Reading database ... 126109 files and directories currently installed.)
# Preparing to unpack .../00-libpcap0.8_1.10.1-4ubuntu1.22.04.1_amd64.deb ...
# Unpacking libpcap0.8:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Selecting previously unselected package libbcg729-0:amd64.
# Preparing to unpack .../01-libbcg729-0_1.1.1-2_amd64.deb ...
# Unpacking libbcg729-0:amd64 (1.1.1-2) ...
# Selecting previously unselected package liblua5.2-0:amd64.
# Preparing to unpack .../02-liblua5.2-0_5.2.4-2_amd64.deb ...
# Unpacking liblua5.2-0:amd64 (5.2.4-2) ...
# Selecting previously unselected package libnl-genl-3-200:amd64.
# Preparing to unpack .../03-libnl-genl-3-200_3.5.0-0.1_amd64.deb ...
# Unpacking libnl-genl-3-200:amd64 (3.5.0-0.1) ...
# Selecting previously unselected package libsmi2ldbl:amd64.
# Preparing to unpack .../04-libsmi2ldbl_0.4.8+dfsg2-16_amd64.deb ...
# Unpacking libsmi2ldbl:amd64 (0.4.8+dfsg2-16) ...
# Selecting previously unselected package libspandsp2:amd64.
# Preparing to unpack .../05-libspandsp2_0.0.6+dfsg-2_amd64.deb ...
# Unpacking libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Selecting previously unselected package libspeexdsp1:amd64.
# Preparing to unpack .../06-libspeexdsp1_1.2~rc1.2-1.1ubuntu3_amd64.deb ...
# Unpacking libspeexdsp1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Selecting previously unselected package libwireshark-data.
# Preparing to unpack .../07-libwireshark-data_3.6.2-2_all.deb ...
# Unpacking libwireshark-data (3.6.2-2) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../08-libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libsbc1:amd64.
# Preparing to unpack .../09-libsbc1_1.5-3build2_amd64.deb ...
# Unpacking libsbc1:amd64 (1.5-3build2) ...
# Selecting previously unselected package libwsutil13:amd64.
# Preparing to unpack .../10-libwsutil13_3.6.2-2_amd64.deb ...
# Unpacking libwsutil13:amd64 (3.6.2-2) ...
# Selecting previously unselected package libwiretap12:amd64.
# Preparing to unpack .../11-libwiretap12_3.6.2-2_amd64.deb ...
# Unpacking libwiretap12:amd64 (3.6.2-2) ...
# Selecting previously unselected package libwireshark15:amd64.
# Preparing to unpack .../12-libwireshark15_3.6.2-2_amd64.deb ...
# Unpacking libwireshark15:amd64 (3.6.2-2) ...
# Selecting previously unselected package wireshark-common.
# Preparing to unpack .../13-wireshark-common_3.6.2-2_amd64.deb ...
# Unpacking wireshark-common (3.6.2-2) ...
# Selecting previously unselected package tshark.
# Preparing to unpack .../14-tshark_3.6.2-2_amd64.deb ...
# Unpacking tshark (3.6.2-2) ...
# Setting up libsbc1:amd64 (1.5-3build2) ...
# Setting up libbcg729-0:amd64 (1.1.1-2) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libsmi2ldbl:amd64 (0.4.8+dfsg2-16) ...
# Setting up libwsutil13:amd64 (3.6.2-2) ...
# Setting up libpcap0.8:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Setting up libwiretap12:amd64 (3.6.2-2) ...
# Setting up libwireshark-data (3.6.2-2) ...
# Setting up liblua5.2-0:amd64 (5.2.4-2) ...
# Setting up libnl-genl-3-200:amd64 (3.5.0-0.1) ...
# Setting up libspeexdsp1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Setting up libwireshark15:amd64 (3.6.2-2) ...
# Setting up wireshark-common (3.6.2-2) ...
# Setting up tshark (3.6.2-2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...

# %%
# CS 293N: Multi-PCAP Alignment with Shared video_sent.1.log (Stream ID or Fallback Temporal Matching)

# === CONFIGURATION ===
PCAP_DIR = '/content/CS293NProject/pcap_qoe'
VIDEO_LOG_PATH = '/content/CS293NProject/withPcap_5k_trim6m_shape6m_pfifo_latency100/video_sent.1.log'
FILTER_IP = '128.111.5.228'
WINDOW_SIZE = 10
SLIDE_STEP = 1

# === LOAD FULL VIDEO LOG FILE ===
video_cols = ['timestamp', 'channel', 'session_id', 'stream_id', 'user_id', 'stream_id1', 'stream_id2',
              'video_ts', 'format', 'size', 'ssim', 'cwnd', 'in_flight', 'rtt',
              'send_time', 'acked_time', 'buffer', 'cum_rebuf', 'uuid']

video_df = pd.read_csv(VIDEO_LOG_PATH, names=video_cols, header=None, index_col=False)
video_df['timestamp'] = pd.to_numeric(video_df['timestamp'], errors='coerce')
video_df['timestamp_sec'] = video_df['timestamp'] / 1000.0
video_df['timestamp'] = pd.to_datetime(video_df['timestamp_sec'], unit='s')
#video_df['bin'] = video_df['timestamp'].dt.floor('10s')

print("✅ Loaded full video_sent log with", len(video_df), "entries")

# convert video_df to csv
video_df.to_csv('/content/video_df.csv', index=False)
#print(video_df.head())
# Out:
# ✅ Loaded full video_sent log with 33218 entries

# %%
# === PREP OUTPUT FILE ===
output_csv_path = "/content/modeling_dataset.csv"
with open(output_csv_path, "w") as f:
    f.write("bin_start,packet_count,total_bytes,avg_packet_size,avg_inter_packet_delay,std_inter_packet_delay,chunk_count,avg_ssim,avg_format,avg_chunk_size\n")

# === LOOP OVER PCAP FILES ===
all_chunks = []
pcap_files = sorted(glob.glob(os.path.join(PCAP_DIR, '*.pcap.pcap')))
print(f"📂 Found {len(pcap_files)} PCAPs")

for pcap_path in pcap_files:
    base_name = os.path.basename(pcap_path).replace('.pcap.pcap', '')
    output_file = f"/content/filtered_{base_name}.csv"

    # Extract user_id from filename
    user_number = base_name.split('_')[2]  # e.g. '48' from 'qoe_on_48_profile7'
    user_id = f"jaber{user_number}"

    # Filter the video log for this user only
    user_video_df = video_df[video_df['user_id'] == user_id] # Filter to just the matching user_id

    # Run TShark to extract only relevant packets
    # !tshark -r "{pcap_path}" -Y "ip.src == {FILTER_IP}" -T fields \
        -e frame.time_epoch -e ip.src -e ip.dst -e frame.len \
        -E header=n -E separator=, > "{output_file}"

    with open(output_file) as f:
        lines = f.readlines()

    if len(lines) == 0:
        print(f"⚠️ No packets found in {pcap_path}, skipping.")
        continue

    # Load packet data
    packet_df = pd.read_csv(output_file, names=['epoch', 'ip_src', 'ip_dst', 'length'], header=None)
    packet_df['timestamp'] = pd.to_datetime(packet_df['epoch'], unit='s', errors='coerce')

    # Align sliding windows
    start_time = max(packet_df['timestamp'].min(), user_video_df['timestamp'].min())
    end_time = min(packet_df['timestamp'].max(), user_video_df['timestamp'].max())

    current = start_time
    while current + timedelta(seconds=WINDOW_SIZE) <= end_time: #step through the 10s interval
        window_start = current
        window_end = current + timedelta(seconds=WINDOW_SIZE)

        #extract the packets and video logs from the specified window
        packets = packet_df[(packet_df['timestamp'] >= window_start) & (packet_df['timestamp'] < window_end)]
        video = user_video_df[(user_video_df['timestamp'] >= window_start) & (user_video_df['timestamp'] < window_end)]

        if packets.empty or video.empty:
            current += timedelta(seconds=SLIDE_STEP)
            continue

        # Packet features
        total_bytes = packets['length'].astype(float).sum() #sum of all packets in the interval
        avg_packet_size = packets['length'].astype(float).mean()
        packet_count = len(packets)

        timestamps = packets['timestamp'].sort_values().values
        if len(timestamps) > 1:
            inter_arrival_times = (timestamps[1:] - timestamps[:-1]).astype('timedelta64[ms]').astype(float)
            avg_inter_packet_delay = inter_arrival_times.mean()
            std_inter_packet_delay = inter_arrival_times.std()
        else:
            avg_inter_packet_delay = 0
            std_inter_packet_delay = 0

        # Video features
        avg_ssim = video['ssim'].astype(float).mean()
        chunk_count = len(video)
        avg_format = video['format'].mode()[0] if not video['format'].mode().empty else None
        avg_size = video['size'].astype(float).mean()

        with open(output_csv_path, "a") as f:
            f.write(f"{window_start},{packet_count},{total_bytes},{avg_packet_size},{avg_inter_packet_delay},{std_inter_packet_delay},{chunk_count},{avg_ssim},{avg_format},{avg_size}\n")

        current += timedelta(seconds=SLIDE_STEP)

    print(f"✅ Session {base_name}: Sliding windows completed")

print("\n📊 Sliding window feature extraction complete. Appended to:", output_csv_path)
# Out:
# 📂 Found 990 PCAPs
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile1.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile1: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile10: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile2: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile3: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile4: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile5: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile6: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile7.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile7: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile8.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile8: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_10_profile9.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_10_profile9: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile1.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile1: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile10: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile2: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile3: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile4: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile5: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile6: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile7.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile7: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile8.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile8: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_11_profile9.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_11_profile9: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile1.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile1: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile10: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile2: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile3: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile4: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile5: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile6: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile7.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile7: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile8.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile8: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_12_profile9.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_12_profile9: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile1.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile1: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile10: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile2: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile3: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile4: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile5: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile6: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_13_profile7.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile8.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile8: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_13_profile9.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_13_profile9: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile1.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile1: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile10: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile2: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile3: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile4: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile5: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile6: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile7.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile7: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile8.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile8: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_14_profile9.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_14_profile9: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile1.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile1: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile10: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile2: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile3: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile4: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile5: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile6: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile7.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile7: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile8.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile8: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_15_profile9.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_15_profile9: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_16_profile1.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_16_profile1: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_16_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_16_profile10: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_16_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_16_profile2: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_16_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_16_profile3: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_16_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_16_profile4: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_16_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_16_profile5: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_16_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_16_profile6: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_16_profile7.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_16_profile7: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_99_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile10.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_99_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile2.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_99_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile3.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_99_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile4.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_99_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile5.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_99_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile6.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile7.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile8.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_99_profile9.pcap.pcap" appears to have been cut short in the middle of a packet.
# ⚠️ No packets found in /content/CS293NProject/pcap_qoe/qoe_on_99_profile9.pcap.pcap, skipping.
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile1.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile1: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile10.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile10: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile2.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile2: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile3.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile3: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile4.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile4: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile5.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile5: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile6.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile6: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile7.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile7: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile8.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile8: Sliding windows completed
# Running as user "root" and group "root". This could be dangerous.
# tshark: The file "/content/CS293NProject/pcap_qoe/qoe_on_9_profile9.pcap.pcap" appears to have been cut short in the middle of a packet.
# ✅ Session qoe_on_9_profile9: Sliding windows completed
#
# 📊 Sliding window feature extraction complete. Appended to: /content/modeling_dataset.csv

# %%
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder
# from sklearn.metrics import classification_report, accuracy_score

# # === Load dataset ===
# df = pd.read_csv("/content/modeling_dataset.csv")

# # === Drop rows with missing labels ===
# df = df.dropna(subset=['avg_format'])

# # === Define features and target ===
# features = [
#     'packet_count',
#     'total_bytes',
#     'avg_packet_size',
#     'avg_inter_packet_delay',
#     'std_inter_packet_delay'
# ]

# X = df[features].fillna(0)

# y = df['avg_format']

# # === Encode the target variable AFTER dropping rows with missing labels ===
# le = LabelEncoder()
# y_encoded = le.fit_transform(y)

# # === Train/test split ===
# X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# # === Train model ===
# clf = RandomForestClassifier(n_estimators=100, random_state=42)
# clf.fit(X_train, y_train)

# # === Evaluate ===
# y_pred = clf.predict(X_test)
# print("✅ Accuracy:", accuracy_score(y_test, y_pred))
# print("\n📊 Classification Report:")
# from sklearn.utils.multiclass import unique_labels
# labels = unique_labels(y_test, y_pred)
# print(classification_report(y_test, y_pred, labels=labels, target_names=le.inverse_transform(labels)))
