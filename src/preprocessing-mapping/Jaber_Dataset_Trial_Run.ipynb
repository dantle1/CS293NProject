# %%
# !git clone https://github.com/dantle1/CS293NProject.git
# Out:
# Cloning into 'CS293NProject'...
# remote: Enumerating objects: 1107, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 1107 (delta 1), reused 0 (delta 0), pack-reused 1100 (from 5)
# Receiving objects: 100% (1107/1107), 1.22 GiB | 29.20 MiB/s, done.
# Resolving deltas: 100% (959/959), done.
# Updating files: 100% (1061/1061), done.

# %%
# TShark Packet Extraction Script for Google Colab (Filtered by IP)
# Project: CS 293N - Raw Packet Filtering from PCAP

import os
import pandas as pd
from datetime import datetime

# %%
# Install TShark
# !apt-get install -y tshark

folder_num = 6 #Assign this variable based on which folder we are executing

folder_name = f"puffer_6M_profile_on50_{folder_num}"
FOLDER = os.path.join('/content/CS293NProject', folder_name)
PCAP_FILE = os.path.join(FOLDER, f"{folder_name}.pcap")
VIDEO_SENT_LOG = os.path.join(FOLDER, 'video_sent.1.log')
OUTPUT_FILE = f"/content/filtered_packets_{folder_num}.csv"
FILTER_IP = '128.111.5.228'
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libbcg729-0 libc-ares2 liblua5.2-0 libnl-genl-3-200 libpcap0.8 libsbc1
#   libsmi2ldbl libspandsp2 libspeexdsp1 libwireshark-data libwireshark15
#   libwiretap12 libwsutil13 wireshark-common
# Suggested packages:
#   snmp-mibs-downloader geoipupdate geoip-database geoip-database-extra
#   libjs-leaflet libjs-leaflet.markercluster wireshark-doc
# The following NEW packages will be installed:
#   libbcg729-0 libc-ares2 liblua5.2-0 libnl-genl-3-200 libpcap0.8 libsbc1
#   libsmi2ldbl libspandsp2 libspeexdsp1 libwireshark-data libwireshark15
#   libwiretap12 libwsutil13 tshark wireshark-common
# 0 upgraded, 15 newly installed, 0 to remove and 35 not upgraded.
# Need to get 23.0 MB of archives.
# After this operation, 120 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap0.8 amd64 1.10.1-4ubuntu1.22.04.1 [145 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbcg729-0 amd64 1.1.1-2 [32.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblua5.2-0 amd64 5.2.4-2 [125 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnl-genl-3-200 amd64 3.5.0-0.1 [12.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsmi2ldbl amd64 0.4.8+dfsg2-16 [100 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libspeexdsp1 amd64 1.2~rc1.2-1.1ubuntu3 [42.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwireshark-data all 3.6.2-2 [1,647 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsbc1 amd64 1.5-3build2 [34.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwsutil13 amd64 3.6.2-2 [99.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwiretap12 amd64 3.6.2-2 [255 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwireshark15 amd64 3.6.2-2 [19.5 MB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 wireshark-common amd64 3.6.2-2 [473 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tshark amd64 3.6.2-2 [157 kB]
# Fetched 23.0 MB in 1s (18.4 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package libpcap0.8:amd64.
# (Reading database ... 126109 files and directories currently installed.)
# Preparing to unpack .../00-libpcap0.8_1.10.1-4ubuntu1.22.04.1_amd64.deb ...
# Unpacking libpcap0.8:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Selecting previously unselected package libbcg729-0:amd64.
# Preparing to unpack .../01-libbcg729-0_1.1.1-2_amd64.deb ...
# Unpacking libbcg729-0:amd64 (1.1.1-2) ...
# Selecting previously unselected package liblua5.2-0:amd64.
# Preparing to unpack .../02-liblua5.2-0_5.2.4-2_amd64.deb ...
# Unpacking liblua5.2-0:amd64 (5.2.4-2) ...
# Selecting previously unselected package libnl-genl-3-200:amd64.
# Preparing to unpack .../03-libnl-genl-3-200_3.5.0-0.1_amd64.deb ...
# Unpacking libnl-genl-3-200:amd64 (3.5.0-0.1) ...
# Selecting previously unselected package libsmi2ldbl:amd64.
# Preparing to unpack .../04-libsmi2ldbl_0.4.8+dfsg2-16_amd64.deb ...
# Unpacking libsmi2ldbl:amd64 (0.4.8+dfsg2-16) ...
# Selecting previously unselected package libspandsp2:amd64.
# Preparing to unpack .../05-libspandsp2_0.0.6+dfsg-2_amd64.deb ...
# Unpacking libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Selecting previously unselected package libspeexdsp1:amd64.
# Preparing to unpack .../06-libspeexdsp1_1.2~rc1.2-1.1ubuntu3_amd64.deb ...
# Unpacking libspeexdsp1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Selecting previously unselected package libwireshark-data.
# Preparing to unpack .../07-libwireshark-data_3.6.2-2_all.deb ...
# Unpacking libwireshark-data (3.6.2-2) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../08-libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libsbc1:amd64.
# Preparing to unpack .../09-libsbc1_1.5-3build2_amd64.deb ...
# Unpacking libsbc1:amd64 (1.5-3build2) ...
# Selecting previously unselected package libwsutil13:amd64.
# Preparing to unpack .../10-libwsutil13_3.6.2-2_amd64.deb ...
# Unpacking libwsutil13:amd64 (3.6.2-2) ...
# Selecting previously unselected package libwiretap12:amd64.
# Preparing to unpack .../11-libwiretap12_3.6.2-2_amd64.deb ...
# Unpacking libwiretap12:amd64 (3.6.2-2) ...
# Selecting previously unselected package libwireshark15:amd64.
# Preparing to unpack .../12-libwireshark15_3.6.2-2_amd64.deb ...
# Unpacking libwireshark15:amd64 (3.6.2-2) ...
# Selecting previously unselected package wireshark-common.
# Preparing to unpack .../13-wireshark-common_3.6.2-2_amd64.deb ...
# Unpacking wireshark-common (3.6.2-2) ...
# Selecting previously unselected package tshark.
# Preparing to unpack .../14-tshark_3.6.2-2_amd64.deb ...
# Unpacking tshark (3.6.2-2) ...
# Setting up libsbc1:amd64 (1.5-3build2) ...
# Setting up libbcg729-0:amd64 (1.1.1-2) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libsmi2ldbl:amd64 (0.4.8+dfsg2-16) ...
# Setting up libwsutil13:amd64 (3.6.2-2) ...
# Setting up libpcap0.8:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Setting up libwiretap12:amd64 (3.6.2-2) ...
# Setting up libwireshark-data (3.6.2-2) ...
# Setting up liblua5.2-0:amd64 (5.2.4-2) ...
# Setting up libnl-genl-3-200:amd64 (3.5.0-0.1) ...
# Setting up libspeexdsp1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Setting up libwireshark15:amd64 (3.6.2-2) ...
# Setting up wireshark-common (3.6.2-2) ...
# Setting up tshark (3.6.2-2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...

# %%
# Run TShark on single PCAP file ===
# !tshark -r "{PCAP_FILE}" -Y "ip.src == {FILTER_IP}" -T fields \
    -e frame.time_epoch -e ip.src -e ip.dst -e frame.len \
    -E header=n -E separator=, > "{OUTPUT_FILE}"

print(f"✅ Packet filtering complete. Saved to: {OUTPUT_FILE}")
# Out:
# Running as user "root" and group "root". This could be dangerous.
# ✅ Packet filtering complete. Saved to: /content/filtered_packets_6.csv

# %%
# Load and Convert TShark Output
df = pd.read_csv(OUTPUT_FILE, header=None,
                 names=['epoch', 'ip_src', 'ip_dst', 'length'])
df['timestamp'] = pd.to_datetime(df['epoch'], unit='s', errors='coerce')

print("Sample filtered packet data:")
print(df.head())
# Out:
# Sample filtered packet data:
#           epoch         ip_src        ip_dst  length  \
# 0  1.742585e+09  128.111.5.228  192.168.40.2      74
# 1  1.742585e+09  128.111.5.228  192.168.40.2      66
# 2  1.742585e+09  128.111.5.228  192.168.40.2      74
# 3  1.742585e+09  128.111.5.228  192.168.40.2      86
# 4  1.742585e+09  128.111.5.228  192.168.40.2     143
#
#                       timestamp
# 0 2025-03-21 19:19:16.285278559
# 1 2025-03-21 19:19:16.296501637
# 2 2025-03-21 19:19:16.297395945
# 3 2025-03-21 19:19:16.298296452
# 4 2025-03-21 19:19:16.298464060

# %%
# Run to download the file in your browser

from google.colab import files
#files.download(f'filtered_packets_{folder_num}.csv')

# %%
with open(OUTPUT_FILE) as f:
    lines = f.readlines()
    print(f"🧾 Filtered packet lines: {len(lines)}")

if len(lines) == 0:
    print("No packets found for the given IP and folder.")
# Out:
# 🧾 Filtered packet lines: 13747

# %%
# Load and Bin Packet Data ===

packet_df = pd.read_csv(OUTPUT_FILE, names=['epoch', 'ip_src', 'ip_dst', 'length'], header=None) #load the data from the csv file
packet_df['timestamp'] = pd.to_datetime(packet_df['epoch'], unit='s', errors='coerce')   # convert to human readable time
packet_df['bin'] = packet_df['timestamp'].dt.floor('10s') # add to nearest timestamp rounded down
#print(packet_df.head())

video_cols = ['timestamp', 'channel', 'session_id', 'stream_id', 'user_id', 'stream_id1', 'stream_id2',
              'video_ts', 'format', 'size', 'ssim', 'cwnd', 'in_flight', 'rtt',
              'send_time', 'acked_time', 'buffer', 'cum_rebuf', 'uuid']

video_df = pd.read_csv(VIDEO_SENT_LOG, names=video_cols, header=None, index_col=False) # sort the dataframe with the header names in video_cols
#print(video_df.head())
video_df['timestamp'] = pd.to_numeric(video_df['timestamp'], errors='coerce')
video_df['timestamp_sec'] = video_df['timestamp'] / 1000.0 #convert to seconds
video_df['timestamp'] = pd.to_datetime(video_df['timestamp_sec'], unit='s') # change to human readable time
video_df['bin'] = video_df['timestamp'].dt.floor('10s') # bin represents the nearest 10s window rounded down

# === STEP 5: Group and Merge ===
grouped_packets = packet_df.groupby('bin')
grouped_video = video_df.groupby('bin')
all_bins = sorted(set(grouped_packets.groups) | set(grouped_video.groups))

chunks = []
for bin_time in all_bins:
    chunks.append({
        'folder': folder_name,
        'bin_start': bin_time,
        'packets': grouped_packets.get_group(bin_time) if bin_time in grouped_packets.groups else pd.DataFrame(),
        'video_sent': grouped_video.get_group(bin_time) if bin_time in grouped_video.groups else pd.DataFrame()
    })

# === STEP 6: Preview ===
print(f"✅ Created {len(chunks)} aligned 10-second chunks\n")
print("🧪 Sample chunk:")
print("Time bin:", chunks[0]['bin_start'])
print("# packets in bin:", len(chunks[0]['packets']))
print("Video logs in bin:", len(chunks[0]['video_sent']))

print(chunks)
# Out:
# ✅ Created 9 aligned 10-second chunks
#
# 🧪 Sample chunk:
# Time bin: 2025-03-21 19:18:00
# # packets in bin: 0
# Video logs in bin: 4
# [{'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:18:00'), 'packets': Empty DataFrame
# Columns: []
# Index: [], 'video_sent':                       timestamp channel  session_id  stream_id user_id  \
# 0 2025-03-21 19:18:02.546999931     cbs           1         11  jaber1
# 1 2025-03-21 19:18:04.750000000     cbs           1         11  jaber1
# 2 2025-03-21 19:18:06.657999992     cbs           1         11  jaber1
# 3 2025-03-21 19:18:08.752000093     cbs           1         11  jaber1
#
#    stream_id1  stream_id2  video_ts        format    size  ...  cwnd  \
# 0   219643018   219643018   3063060  1920x1080-24  523644  ...   132
# 1   219643018   219643018   3243240   1280x720-20  433693  ...   132
# 2   219643018   219643018   3423420  1920x1080-24  468779  ...   132
# 3   219643018   219643018   3603600  1920x1080-24  451593  ...     4
#
#    in_flight    rtt  send_time  acked_time  buffer  cum_rebuf  \
# 0         29  93931     476882      282902   8.155      0.629
# 1          0  93931     624864      276398   7.994      0.629
# 2          0  93931     606548      277091   8.111      0.629
# 3         25  93931     634944      251689   8.016      0.629
#
#                                uuid timestamp_sec                 bin
# 0  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:00
# 1  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:00
# 2  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:00
# 3  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:00
#
# [4 rows x 21 columns]}, {'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:18:10'), 'packets': Empty DataFrame
# Columns: []
# Index: [], 'video_sent':                       timestamp channel  session_id  stream_id user_id  \
# 4 2025-03-21 19:18:11.119999886     cbs           1         11  jaber1
# 5 2025-03-21 19:18:12.844000101     cbs           1         11  jaber1
# 6 2025-03-21 19:18:14.555000067     cbs           1         11  jaber1
# 7 2025-03-21 19:18:16.351000071     cbs           1         11  jaber1
# 8 2025-03-21 19:18:17.655999899     cbs           1         11  jaber1
# 9 2025-03-21 19:18:19.134999990     cbs           1         11  jaber1
#
#    stream_id1  stream_id2  video_ts        format    size  ...  cwnd  \
# 4   219643018   219643018   3783780  1920x1080-24  400835  ...   172
# 5   219643018   219643018   3963960  1920x1080-24  400854  ...   172
# 6   219643018   219643018   4144140  1920x1080-24  417649  ...   180
# 7   219643018   219643018   4324320  1920x1080-24  278588  ...   182
# 8   219643018   219643018   4504500  1920x1080-24  316014  ...   184
# 9   219643018   219643018   4684680  1920x1080-24  362741  ...   176
#
#    in_flight    rtt  send_time  acked_time  buffer  cum_rebuf  \
# 4          0  93931     490575      305965   7.650      0.629
# 5         26  93931     515758      268387   7.928      0.629
# 6          0  93931     517164      288858   8.237      0.629
# 7         27  93931     546614      281090   8.437      0.629
# 8          0  93931     498518      325352   9.164      0.629
# 9          0  93931     497062      261977   9.687      0.629
#
#                                uuid timestamp_sec                 bin
# 4  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:10
# 5  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:10
# 6  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:10
# 7  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:10
# 8  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:10
# 9  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:10
#
# [6 rows x 21 columns]}, {'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:18:20'), 'packets': Empty DataFrame
# Columns: []
# Index: [], 'video_sent':                        timestamp channel  session_id  stream_id user_id  \
# 10 2025-03-21 19:18:21.280999899     cbs           1         11  jaber1
# 11 2025-03-21 19:18:22.951999903     cbs           1         11  jaber1
# 12 2025-03-21 19:18:24.585000038     cbs           1         11  jaber1
# 13 2025-03-21 19:18:26.670000076     cbs           1         11  jaber1
# 14 2025-03-21 19:18:28.526999950     cbs           1         11  jaber1
#
#     stream_id1  stream_id2  video_ts        format    size  ...  cwnd  \
# 10   219643018   219643018   4864860  1920x1080-24  481809  ...   128
# 11   219643018   219643018   5045040   1280x720-20  422567  ...   132
# 12   219643018   219643018   5225220  1920x1080-24  465165  ...   132
# 13   219643018   219643018   5405400  1920x1080-24  409862  ...   120
# 14   219643018   219643018   5585580  1920x1080-24  303539  ...   108
#
#     in_flight    rtt  send_time  acked_time  buffer  cum_rebuf  \
# 10         25  93931     279707      277585   9.560      0.629
# 11          0  93931     411581      321553   9.894      0.629
# 12         30  93931     540893      340559  10.275      0.629
# 13          0  93931     647829      262884  10.186      0.629
# 14          0  93931     591077      263280  10.324      0.629
#
#                                 uuid timestamp_sec                 bin
# 10  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:20
# 11  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:20
# 12  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:20
# 13  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:20
# 14  haSGl4qKM855MwAhCzybEn1cNmSjDI1N  1.742585e+09 2025-03-21 19:18:20
#
# [5 rows x 21 columns]}, {'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:19:10'), 'packets':              epoch         ip_src        ip_dst  length  \
# 0     1.742585e+09  128.111.5.228  192.168.40.2      74
# 1     1.742585e+09  128.111.5.228  192.168.40.2      66
# 2     1.742585e+09  128.111.5.228  192.168.40.2      74
# 3     1.742585e+09  128.111.5.228  192.168.40.2      86
# 4     1.742585e+09  128.111.5.228  192.168.40.2     143
# ...            ...            ...           ...     ...
# 1049  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 1050  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 1051  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 1052  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 1053  1.742585e+09  128.111.5.228  192.168.40.2    1484
#
#                          timestamp                 bin
# 0    2025-03-21 19:19:16.285278559 2025-03-21 19:19:10
# 1    2025-03-21 19:19:16.296501637 2025-03-21 19:19:10
# 2    2025-03-21 19:19:16.297395945 2025-03-21 19:19:10
# 3    2025-03-21 19:19:16.298296452 2025-03-21 19:19:10
# 4    2025-03-21 19:19:16.298464060 2025-03-21 19:19:10
# ...                            ...                 ...
# 1049 2025-03-21 19:19:19.992039680 2025-03-21 19:19:10
# 1050 2025-03-21 19:19:19.994021177 2025-03-21 19:19:10
# 1051 2025-03-21 19:19:19.996002436 2025-03-21 19:19:10
# 1052 2025-03-21 19:19:19.997977257 2025-03-21 19:19:10
# 1053 2025-03-21 19:19:19.999958754 2025-03-21 19:19:10
#
# [1054 rows x 6 columns], 'video_sent':                        timestamp channel  session_id  stream_id user_id  \
# 15 2025-03-21 19:19:18.339999914     cbs           1         11  jaber1
# 16 2025-03-21 19:19:18.493000031     cbs           1         11  jaber1
# 17 2025-03-21 19:19:18.763000011     cbs           1         11  jaber1
# 18 2025-03-21 19:19:19.148999929     cbs           1         11  jaber1
# 19 2025-03-21 19:19:19.859999895     cbs           1         11  jaber1
#
#     stream_id1  stream_id2  video_ts        format    size  ...  cwnd  \
# 15  1403997279  1403997279         0    426x240-26   30382  ...    11
# 16  1403997279  1403997279    180180   1280x720-26   99621  ...    35
# 17  1403997279  1403997279    360360   1280x720-24  202504  ...    18
# 18  1403997279  1403997279    540540  1920x1080-24  457180  ...    10
# 19  1403997279  1403997279    720720  1920x1080-24  391182  ...    11
#
#     in_flight   rtt  send_time  acked_time  buffer  cum_rebuf  \
# 15          0  1404     168264     1009971   0.000      0.000
# 16          0   509      48629      680490   2.002      0.000
# 17          0   509     100580      523092   3.765      0.206
# 18          9   509      23673      514383   5.396      0.206
# 19          0   509      21306      539733   6.688      0.206
#
#                                 uuid timestamp_sec                 bin
# 15  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:10
# 16  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:10
# 17  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:10
# 18  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:10
# 19  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:10
#
# [5 rows x 21 columns]}, {'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:19:20'), 'packets':              epoch         ip_src        ip_dst  length  \
# 1054  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 1055  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 1056  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 1057  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 1058  1.742585e+09  128.111.5.228  192.168.40.2    1484
# ...            ...            ...           ...     ...
# 5155  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 5156  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 5157  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 5158  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 5159  1.742585e+09  128.111.5.228  192.168.40.2    1484
#
#                          timestamp                 bin
# 1054 2025-03-21 19:19:20.001933575 2025-03-21 19:19:20
# 1055 2025-03-21 19:19:20.003864050 2025-03-21 19:19:20
# 1056 2025-03-21 19:19:20.005890369 2025-03-21 19:19:20
# 1057 2025-03-21 19:19:20.007817268 2025-03-21 19:19:20
# 1058 2025-03-21 19:19:20.009847164 2025-03-21 19:19:20
# ...                            ...                 ...
# 5155 2025-03-21 19:19:29.991042376 2025-03-21 19:19:20
# 5156 2025-03-21 19:19:29.992773056 2025-03-21 19:19:20
# 5157 2025-03-21 19:19:29.994712353 2025-03-21 19:19:20
# 5158 2025-03-21 19:19:29.996726513 2025-03-21 19:19:20
# 5159 2025-03-21 19:19:29.998709917 2025-03-21 19:19:20
#
# [4106 rows x 6 columns], 'video_sent':                        timestamp channel  session_id  stream_id user_id  \
# 20 2025-03-21 19:19:20.448999882     cbs           1         11  jaber1
# 21 2025-03-21 19:19:21.372999907     cbs           1         11  jaber1
# 22 2025-03-21 19:19:22.349999905     cbs           1         11  jaber1
# 23 2025-03-21 19:19:23.585000038     cbs           1         11  jaber1
# 24 2025-03-21 19:19:25.223999977     cbs           1         11  jaber1
# 25 2025-03-21 19:19:27.069000006     cbs           1         11  jaber1
# 26 2025-03-21 19:19:28.026000023     cbs           1         11  jaber1
# 27 2025-03-21 19:19:28.969000101     cbs           1         11  jaber1
# 28 2025-03-21 19:19:29.990000010     cbs           1         11  jaber1
#
#     stream_id1  stream_id2  video_ts        format     size  ...  cwnd  \
# 20  1403997279  1403997279    900900  1920x1080-22   579192  ...    10
# 21  1403997279  1403997279   1081080  1920x1080-22   617335  ...    20
# 22  1403997279  1403997279   1261260  1920x1080-22   649152  ...    10
# 23  1403997279  1403997279   1441440  1920x1080-22   610976  ...    22
# 24  1403997279  1403997279   1621620  1920x1080-22  1064663  ...    14
# 25  1403997279  1403997279   1801800  1920x1080-22   603682  ...    10
# 26  1403997279  1403997279   1981980  1920x1080-22   586554  ...    16
# 27  1403997279  1403997279   2162160  1920x1080-22   584665  ...    22
# 28  1403997279  1403997279   2342340  1920x1080-22   591356  ...    12
#
#     in_flight  rtt  send_time  acked_time  buffer  cum_rebuf  \
# 20         10  509      20743      537437   8.103      0.206
# 21          0  509      38260      679654   9.183      0.206
# 22          0  485      20844      550109  10.206      0.206
# 23         21  302      52842      235341  10.967      0.206
# 24          0  302      63671      233430  11.362      0.206
# 25         10  302      20388      706280  11.512      0.206
# 26          0  302      25055      585373  12.558      0.206
# 27         21  302      33174      631670  13.623      0.206
# 28          0  302      25850      716704  14.599      0.206
#
#                                 uuid timestamp_sec                 bin
# 20  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
# 21  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
# 22  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
# 23  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
# 24  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
# 25  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
# 26  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
# 27  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
# 28  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:20
#
# [9 rows x 21 columns]}, {'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:19:30'), 'packets':              epoch         ip_src        ip_dst  length  \
# 5160  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 5161  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 5162  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 5163  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 5164  1.742585e+09  128.111.5.228  192.168.40.2    1484
# ...            ...            ...           ...     ...
# 7552  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 7553  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 7554  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 7555  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 7556  1.742585e+09  128.111.5.228  192.168.40.2    1484
#
#                          timestamp                 bin
# 5160 2025-03-21 19:19:30.000679255 2025-03-21 19:19:30
# 5161 2025-03-21 19:19:30.002664089 2025-03-21 19:19:30
# 5162 2025-03-21 19:19:30.004639626 2025-03-21 19:19:30
# 5163 2025-03-21 19:19:30.006616831 2025-03-21 19:19:30
# 5164 2025-03-21 19:19:30.008593082 2025-03-21 19:19:30
# ...                            ...                 ...
# 7552 2025-03-21 19:19:39.992063999 2025-03-21 19:19:30
# 7553 2025-03-21 19:19:39.994044065 2025-03-21 19:19:30
# 7554 2025-03-21 19:19:39.995974302 2025-03-21 19:19:30
# 7555 2025-03-21 19:19:39.997999191 2025-03-21 19:19:30
# 7556 2025-03-21 19:19:39.999978304 2025-03-21 19:19:30
#
# [2397 rows x 6 columns], 'video_sent':                        timestamp channel  session_id  stream_id user_id  \
# 29 2025-03-21 19:19:31.887000084     cbs           1         11  jaber1
# 30 2025-03-21 19:19:33.841000080     cbs           1         11  jaber1
# 31 2025-03-21 19:19:35.839999914     cbs           1         11  jaber1
# 32 2025-03-21 19:19:37.921999931     cbs           1         11  jaber1
# 33 2025-03-21 19:19:39.841000080     cbs           1         11  jaber1
#
#     stream_id1  stream_id2  video_ts        format    size  ...  cwnd  \
# 29  1403997279  1403997279   2522520  1920x1080-22  594042  ...    18
# 30  1403997279  1403997279   2702700  1920x1080-22  598350  ...     4
# 31  1403997279  1403997279   2882880  1920x1080-22  583821  ...    12
# 32  1403997279  1403997279   3063060  1920x1080-22  740626  ...    30
# 33  1403997279  1403997279   3243240  1920x1080-22  737085  ...    10
#
#     in_flight  rtt  send_time  acked_time  buffer  cum_rebuf  \
# 29          0  302     110714      217860  14.707      0.206
# 30          0  302      43294      210323  14.751      0.206
# 31          0  302      21035      560007  14.755      0.206
# 32          0  302      44717      664268  14.795      0.206
# 33          0  302      21022      703024  14.817      0.206
#
#                                 uuid timestamp_sec                 bin
# 29  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:30
# 30  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:30
# 31  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:30
# 32  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:30
# 33  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:30
#
# [5 rows x 21 columns]}, {'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:19:40'), 'packets':              epoch         ip_src        ip_dst  length  \
# 7557  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 7558  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 7559  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 7560  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 7561  1.742585e+09  128.111.5.228  192.168.40.2    1484
# ...            ...            ...           ...     ...
# 9929  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 9930  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 9931  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 9932  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 9933  1.742585e+09  128.111.5.228  192.168.40.2    1484
#
#                          timestamp                 bin
# 7557 2025-03-21 19:19:40.001956462 2025-03-21 19:19:40
# 7558 2025-03-21 19:19:40.003993511 2025-03-21 19:19:40
# 7559 2025-03-21 19:19:40.005979538 2025-03-21 19:19:40
# 7560 2025-03-21 19:19:40.008004904 2025-03-21 19:19:40
# 7561 2025-03-21 19:19:40.009985924 2025-03-21 19:19:40
# ...                            ...                 ...
# 9929 2025-03-21 19:19:49.991967201 2025-03-21 19:19:40
# 9930 2025-03-21 19:19:49.993998289 2025-03-21 19:19:40
# 9931 2025-03-21 19:19:49.995924950 2025-03-21 19:19:40
# 9932 2025-03-21 19:19:49.997960329 2025-03-21 19:19:40
# 9933 2025-03-21 19:19:49.999936819 2025-03-21 19:19:40
#
# [2377 rows x 6 columns], 'video_sent':                        timestamp channel  session_id  stream_id user_id  \
# 34 2025-03-21 19:19:41.841000080     cbs           1         11  jaber1
# 35 2025-03-21 19:19:43.888999939     cbs           1         11  jaber1
# 36 2025-03-21 19:19:45.839999914     cbs           1         11  jaber1
# 37 2025-03-21 19:19:47.839999914     cbs           1         11  jaber1
# 38 2025-03-21 19:19:49.900000095     cbs           1         11  jaber1
#
#     stream_id1  stream_id2  video_ts        format    size  ...  cwnd  \
# 34  1403997279  1403997279   3423420  1920x1080-22  689553  ...    22
# 35  1403997279  1403997279   3603600  1920x1080-22  656351  ...    10
# 36  1403997279  1403997279   3783780  1920x1080-22  594042  ...    18
# 37  1403997279  1403997279   3963960  1920x1080-22  579748  ...    18
# 38  1403997279  1403997279   4144140  1920x1080-22  602723  ...    20
#
#     in_flight  rtt  send_time  acked_time  buffer  cum_rebuf  \
# 34          0  302      27997      589531  14.840      0.206
# 35          0  302      31416      486467  14.861      0.206
# 36          0  302      33588      411576  14.883      0.206
# 37          0  302      25280      367452  14.906      0.206
# 38          0  302      25448      546698  14.927      0.206
#
#                                 uuid timestamp_sec                 bin
# 34  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:40
# 35  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:40
# 36  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:40
# 37  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:40
# 38  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:40
#
# [5 rows x 21 columns]}, {'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:19:50'), 'packets':               epoch         ip_src        ip_dst  length  \
# 9934   1.742585e+09  128.111.5.228  192.168.40.2    1484
# 9935   1.742585e+09  128.111.5.228  192.168.40.2    1484
# 9936   1.742585e+09  128.111.5.228  192.168.40.2    1484
# 9937   1.742585e+09  128.111.5.228  192.168.40.2    1484
# 9938   1.742585e+09  128.111.5.228  192.168.40.2    1484
# ...             ...            ...           ...     ...
# 11632  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 11633  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 11634  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 11635  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 11636  1.742585e+09  128.111.5.228  192.168.40.2    1484
#
#                           timestamp                 bin
# 9934  2025-03-21 19:19:50.001914024 2025-03-21 19:19:50
# 9935  2025-03-21 19:19:50.003896475 2025-03-21 19:19:50
# 9936  2025-03-21 19:19:50.005870819 2025-03-21 19:19:50
# 9937  2025-03-21 19:19:50.007802010 2025-03-21 19:19:50
# 9938  2025-03-21 19:19:50.009781122 2025-03-21 19:19:50
# ...                             ...                 ...
# 11632 2025-03-21 19:19:59.956932306 2025-03-21 19:19:50
# 11633 2025-03-21 19:19:59.958863020 2025-03-21 19:19:50
# 11634 2025-03-21 19:19:59.960890055 2025-03-21 19:19:50
# 11635 2025-03-21 19:19:59.980221510 2025-03-21 19:19:50
# 11636 2025-03-21 19:19:59.982200384 2025-03-21 19:19:50
#
# [1703 rows x 6 columns], 'video_sent':                        timestamp channel  session_id  stream_id user_id  \
# 39 2025-03-21 19:19:52.401000023     cbs           1         11  jaber1
# 40 2025-03-21 19:19:54.601000071     cbs           1         11  jaber1
# 41 2025-03-21 19:19:56.673000097     cbs           1         11  jaber1
# 42 2025-03-21 19:19:58.926000118     cbs           1         11  jaber1
#
#     stream_id1  stream_id2  video_ts        format    size  ...  cwnd  \
# 39  1403997279  1403997279   4324320  1920x1080-22  420355  ...    22
# 40  1403997279  1403997279   4504500  1920x1080-22  468596  ...    23
# 41  1403997279  1403997279   4684680  1920x1080-22  538537  ...    20
# 42  1403997279  1403997279   4864860  1920x1080-22  705973  ...    50
#
#     in_flight  rtt  send_time  acked_time  buffer  cum_rebuf  \
# 39         22  302     137132      243861  14.391      0.206
# 40          0  302     117864      263919  14.192      0.206
# 41          0  302     125153      154356  14.107      0.206
# 42         38  302     198538      301937  13.926      0.206
#
#                                 uuid timestamp_sec                 bin
# 39  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:50
# 40  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:50
# 41  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:50
# 42  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:19:50
#
# [4 rows x 21 columns]}, {'folder': 'puffer_6M_profile_on50_6', 'bin_start': Timestamp('2025-03-21 19:20:00'), 'packets':               epoch         ip_src        ip_dst  length  \
# 11637  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 11638  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 11639  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 11640  1.742585e+09  128.111.5.228  192.168.40.2    1484
# 11641  1.742585e+09  128.111.5.228  192.168.40.2    1484
# ...             ...            ...           ...     ...
# 13742  1.742585e+09  128.111.5.228  192.168.40.2      66
# 13743  1.742585e+09  128.111.5.228  192.168.40.2      66
# 13744  1.742585e+09  128.111.5.228  192.168.40.2      66
# 13745  1.742585e+09  128.111.5.228  192.168.40.2      66
# 13746  1.742585e+09  128.111.5.228  192.168.40.2      66
#
#                           timestamp                 bin
# 11637 2025-03-21 19:20:00.075634480 2025-03-21 19:20:00
# 11638 2025-03-21 19:20:00.077555656 2025-03-21 19:20:00
# 11639 2025-03-21 19:20:00.079580069 2025-03-21 19:20:00
# 11640 2025-03-21 19:20:00.081564903 2025-03-21 19:20:00
# 11641 2025-03-21 19:20:00.083490372 2025-03-21 19:20:00
# ...                             ...                 ...
# 13742 2025-03-21 19:20:09.388776302 2025-03-21 19:20:00
# 13743 2025-03-21 19:20:09.388828754 2025-03-21 19:20:00
# 13744 2025-03-21 19:20:09.388878107 2025-03-21 19:20:00
# 13745 2025-03-21 19:20:09.388928413 2025-03-21 19:20:00
# 13746 2025-03-21 19:20:09.388988495 2025-03-21 19:20:00
#
# [2110 rows x 6 columns], 'video_sent':                        timestamp channel  session_id  stream_id user_id  \
# 43 2025-03-21 19:20:02.066999911     cbs           1         11  jaber1
# 44 2025-03-21 19:20:05.306999922     cbs           1         11  jaber1
# 45 2025-03-21 19:20:07.963999987     cbs           1         11  jaber1
# 46 2025-03-21 19:20:08.852999926     cbs           1         11  jaber1
#
#     stream_id1  stream_id2  video_ts        format    size  ...  cwnd  \
# 43  1403997279  1403997279   5045040  1920x1080-22  707508  ...    46
# 44  1403997279  1403997279   5225220  1920x1080-22  678699  ...    44
# 45  1403997279  1403997279   5405400  1920x1080-22  599419  ...    66
# 46  1403997279  1403997279   5585580  1920x1080-22  457857  ...    10
#
#     in_flight  rtt  send_time  acked_time  buffer  cum_rebuf  \
# 43          0  302     309370      225698  12.784      0.206
# 44         33  302     247811      192130  11.536      0.206
# 45          0  302      80472      712934  10.911      0.206
# 46          0  302      21215      713878  12.021      0.206
#
#                                 uuid timestamp_sec                 bin
# 43  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:20:00
# 44  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:20:00
# 45  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:20:00
# 46  EqLtZVw76zWqYh0xXFgWavgRGXep41Vh  1.742585e+09 2025-03-21 19:20:00
#
# [4 rows x 21 columns]}]

# %%
for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}: {chunk['bin_start']}  | Packets: {len(chunk['packets'])}, Video logs: {len(chunk['video_sent'])}")
# Out:
# Chunk 1: 2025-03-21 19:18:00  | Packets: 0, Video logs: 4
# Chunk 2: 2025-03-21 19:18:10  | Packets: 0, Video logs: 6
# Chunk 3: 2025-03-21 19:18:20  | Packets: 0, Video logs: 5
# Chunk 4: 2025-03-21 19:19:10  | Packets: 1054, Video logs: 5
# Chunk 5: 2025-03-21 19:19:20  | Packets: 4106, Video logs: 9
# Chunk 6: 2025-03-21 19:19:30  | Packets: 2397, Video logs: 5
# Chunk 7: 2025-03-21 19:19:40  | Packets: 2377, Video logs: 5
# Chunk 8: 2025-03-21 19:19:50  | Packets: 1703, Video logs: 4
# Chunk 9: 2025-03-21 19:20:00  | Packets: 2110, Video logs: 4
